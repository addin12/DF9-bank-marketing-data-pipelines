# %%
import numpy as np
import pandas as pd
np.random.seed(0)

# %%
df = pd.read_csv("bank-additional-full-masked.csv", sep=";")
df
# Out:
#        client_id  age          job  marital            education  default  \
# 0              1   56    housemaid  married             basic.4y       no
# 1              2   57     services  married          high.school  unknown
# 2              3   37     services  married          high.school       no
# 3              4   40       admin.  married             basic.6y       no
# 4              5   56     services  married          high.school       no
# ...          ...  ...          ...      ...                  ...      ...
# 41183      41184   73      retired  married  professional.course       no
# 41184      41185   46  blue-collar  married  professional.course       no
# 41185      41186   56      retired  married    university.degree       no
# 41186      41187   44   technician  married  professional.course       no
# 41187      41188   74      retired  married  professional.course       no
#
#       housing loan    contact month  ...  campaign pdays  previous  \
# 0          no   no  telephone   may  ...         1   999         0
# 1          no   no  telephone   may  ...         1   999         0
# 2         yes   no  telephone   may  ...         1   999         0
# 3          no   no  telephone   may  ...         1   999         0
# 4          no  yes  telephone   may  ...         1   999         0
# ...       ...  ...        ...   ...  ...       ...   ...       ...
# 41183     yes   no   cellular   nov  ...         1   999         0
# 41184      no   no   cellular   nov  ...         1   999         0
# 41185     yes   no   cellular   nov  ...         2   999         0
# 41186      no   no   cellular   nov  ...         1   999         0
# 41187     yes   no   cellular   nov  ...         3   999         1
#
#           poutcome  emp.var.rate  cons.price.idx cons.conf.idx  euribor3m  \
# 0      nonexistent           1.1          93.994         -36.4      4.857
# 1      nonexistent           1.1          93.994         -36.4      4.857
# 2      nonexistent           1.1          93.994         -36.4      4.857
# 3      nonexistent           1.1          93.994         -36.4      4.857
# 4      nonexistent           1.1          93.994         -36.4      4.857
# ...            ...           ...             ...           ...        ...
# 41183  nonexistent          -1.1          94.767         -50.8      1.028
# 41184  nonexistent          -1.1          94.767         -50.8      1.028
# 41185  nonexistent          -1.1          94.767         -50.8      1.028
# 41186  nonexistent          -1.1          94.767         -50.8      1.028
# 41187      failure          -1.1          94.767         -50.8      1.028
#
#        nr.employed    y
# 0           5191.0   no
# 1           5191.0   no
# 2           5191.0   no
# 3           5191.0   no
# 4           5191.0   no
# ...            ...  ...
# 41183       4963.6  yes
# 41184       4963.6   no
# 41185       4963.6   no
# 41186       4963.6  yes
# 41187       4963.6   no
#
# [41188 rows x 23 columns]

# %%
df.shape
# Out:
# (41188, 23)

# %%
# df = df.mask(np.random.choice([True, False], size=df.shape, p=[.05,.95]))
df.mask(np.random.rand(*df.shape) < 0.001, inplace=True)

# %%
df
# Out:
#        client_id   age          job  marital            education  default  \
# 0            1.0  56.0    housemaid  married             basic.4y       no
# 1            2.0  57.0     services  married          high.school  unknown
# 2            3.0  37.0     services  married          high.school       no
# 3            4.0  40.0       admin.  married             basic.6y       no
# 4            5.0  56.0     services  married          high.school       no
# ...          ...   ...          ...      ...                  ...      ...
# 41183    41184.0  73.0      retired  married  professional.course       no
# 41184    41185.0  46.0  blue-collar  married  professional.course       no
# 41185    41186.0  56.0      retired  married    university.degree       no
# 41186    41187.0  44.0   technician  married  professional.course       no
# 41187    41188.0  74.0      retired  married  professional.course       no
#
#       housing loan    contact month  ...  campaign  pdays  previous  \
# 0          no   no  telephone   may  ...       1.0  999.0       0.0
# 1          no   no  telephone   may  ...       1.0  999.0       0.0
# 2         yes   no  telephone   may  ...       1.0  999.0       0.0
# 3          no   no  telephone   may  ...       1.0  999.0       0.0
# 4          no  yes  telephone   may  ...       1.0  999.0       0.0
# ...       ...  ...        ...   ...  ...       ...    ...       ...
# 41183     yes   no   cellular   nov  ...       1.0  999.0       0.0
# 41184      no   no   cellular   nov  ...       1.0  999.0       0.0
# 41185     yes   no   cellular   NaN  ...       2.0  999.0       0.0
# 41186      no   no   cellular   nov  ...       1.0  999.0       0.0
# 41187     yes   no   cellular   nov  ...       3.0  999.0       1.0
#
#           poutcome  emp.var.rate  cons.price.idx cons.conf.idx  euribor3m  \
# 0      nonexistent           1.1          93.994         -36.4      4.857
# 1      nonexistent           1.1          93.994         -36.4      4.857
# 2      nonexistent           1.1          93.994         -36.4      4.857
# 3      nonexistent           1.1          93.994         -36.4      4.857
# 4      nonexistent           1.1          93.994         -36.4      4.857
# ...            ...           ...             ...           ...        ...
# 41183  nonexistent          -1.1          94.767         -50.8      1.028
# 41184  nonexistent          -1.1          94.767         -50.8      1.028
# 41185  nonexistent          -1.1          94.767         -50.8      1.028
# 41186  nonexistent          -1.1          94.767         -50.8      1.028
# 41187      failure          -1.1          94.767         -50.8      1.028
#
#        nr.employed    y
# 0           5191.0   no
# 1           5191.0   no
# 2           5191.0   no
# 3           5191.0   no
# 4           5191.0   no
# ...            ...  ...
# 41183       4963.6  yes
# 41184       4963.6   no
# 41185       4963.6   no
# 41186       4963.6  yes
# 41187       4963.6   no
#
# [41188 rows x 23 columns]

# %%
print(df.isna().any(axis=1).sum())
# Out:
# 903

# %%
df.to_csv("bank-additional-full-masked-null.csv",sep=";", index=False)
